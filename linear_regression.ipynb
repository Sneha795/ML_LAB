# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha795/ML_LAB/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Load the data
df = pd.read_csv('sample_data.txt')
X = df[['X1']].values  # Only X1 as feature
y = df['y'].values

# Fit linear regression
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Calculate errors
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")

# Plot actual vs predicted
plt.figure(figsize=(10,6))
plt.scatter(X, y, color='red', label='Actual')
plt.plot(X, y_pred, color='blue', label='Predicted')
plt.xlabel('X1')
plt.ylabel('y')
plt.title('Linear Regression: X1 vs y')
plt.legend()
plt.show()
# Out:
# Root Mean Squared Error (RMSE): 205.32
